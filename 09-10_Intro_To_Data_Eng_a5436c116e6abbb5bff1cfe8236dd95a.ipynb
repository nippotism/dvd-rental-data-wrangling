# %% [markdown]
# # **Week #9-10 - CASE : DVD RENTAL ETL**
#
# Intro to Data Engineering Course - Sekolah Engineer - Pacmann Academy

# %%
# %pip install tabulate
import pandas as pd
from tabulate import tabulate
import warnings 
  
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: tabulate in c:\users\syari\appdata\local\programs\python\python312\lib\site-packages (0.9.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 1. Data Source

# %% [markdown]
# ### 1.1. Data Source I : API

# %% [markdown]
# - Data `city` : https://raw.githubusercontent.com/rahilpacmann/case-data-wrangling-api/main/city.csv

# %%
city_raw = "https://raw.githubusercontent.com/rahilpacmann/case-data-wrangling-api/main/city.csv"

# %% [markdown]
# ### 1.2. Data Source II : API

# %% [markdown]
# - Data `country` : https://raw.githubusercontent.com/rahilpacmann/case-data-wrangling-api/main/country.csv

# %%
country_raw = "https://raw.githubusercontent.com/rahilpacmann/case-data-wrangling-api/main/country.csv"

# %% [markdown]
# ### 1.3. Data Source III : Database

# %% [markdown]
# - ***NOTES : Pastikan anda sudah mempersiapkan Data Source 3. Silahkan lihat "Live Class Preparation" pada Chapter 9***

# %% [markdown]
# - Jika sudah mempersiapkan data source 3 buat koneksi ke database tersebut.
#     - dbname = "dvdrental"
#     - user = "postgres"
#     - password = "qwerty123"
#     - host = "localhost"
#     - port = "5433"

# %%
# Your code here
# Buat koneksi ke database
import psycopg2
from sqlalchemy import create_engine


dbname = "dvdrental"
user = "postgres"
password = "qwerty123"
host = "localhost"
port = "5433"

# Membuat koneksi ke database
engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{dbname}')

# %% [markdown]
# ### 1.4. Requirements (JSON)

# %% [markdown]
# - Requirements :
#     - https://rahilpacmann.github.io/case-data-wrangling-api/requirements_table.json
# - Requirements tersebut meliputi :
#     - Nama tabel
#     - Nama kolom pada setiap tabel
#     - Tipe data pada setiap tabel

# %%
requirements_table_url = 'https://rahilpacmann.github.io/case-data-wrangling-api/requirements_table.json'

# %% [markdown]
# - Load Json

# %%
# Your code here
import urllib.request, json 

with urllib.request.urlopen(requirements_table_url) as url:
    requirements_table = json.load(url)
    
print(requirements_table)
# Out:
# {'actor': [{'column_name': 'actor_id', 'data_type': 'int64'}, {'column_name': 'last_update', 'data_type': 'datetime64[ns]'}, {'column_name': 'first_name', 'data_type': 'object'}, {'column_name': 'last_name', 'data_type': 'object'}], 'store': [{'column_name': 'store_id', 'data_type': 'int64'}, {'column_name': 'manager_staff_id', 'data_type': 'int64'}, {'column_name': 'address_id', 'data_type': 'int64'}, {'column_name': 'last_update', 'data_type': 'datetime64[ns]'}], 'address': [{'column_name': 'last_update', 'data_type': 'datetime64[ns]'}, {'column_name': 'city_id', 'data_type': 'int64'}, {'column_name': 'address_id', 'data_type': 'int64'}, {'column_name': 'district', 'data_type': 'object'}, {'column_name': 'phone', 'data_type': 'object'}, {'column_name': 'postal_code', 'data_type': 'object'}, {'column_name': 'address', 'data_type': 'object'}, {'column_name': 'address2', 'data_type': 'object'}], 'category': [{'column_name': 'category_id', 'data_type': 'int64'}, {'column_name': 'last_update', 'data_type': 'datetime64[ns]'}, {'column_name': 'name', 'data_type': 'object'}], 'city': [{'column_name': 'city_id', 'data_type': 'int64'}, {'column_name': 'country_id', 'data_type': 'int64'}, {'column_name': 'last_update', 'data_type': 'datetime64[ns]'}, {'column_name': 'city', 'data_type': 'object'}], 'country': [{'column_name': 'country_id', 'data_type': 'int64'}, {'column_name': 'last_update', 'data_type': 'datetime64[ns]'}, {'column_name': 'country', 'data_type': 'object'}], 'customer': [{'column_name': 'active', 'data_type': 'int64'}, {'column_name': 'store_id', 'data_type': 'int64'}, {'column_name': 'create_date', 'data_type': 'datetime64[ns]'}, {'column_name': 'last_update', 'data_type': 'datetime64[ns]'}, {'column_name': 'customer_id', 'data_type': 'int64'}, {'column_name': 'address_id', 'data_type': 'int64'}, {'column_name': 'activebool', 'data_type': 'bool'}, {'column_name': 'first_name', 'data_type': 'object'}, {'column_name': 'last_name', 'data_type': 'object'}, {'column_name': 'email', 'data_type': 'object'}], 'film_actor': [{'column_name': 'actor_id', 'data_type': 'int64'}, {'column_name': 'film_id', 'data_type': 'int64'}, {'column_name': 'last_update', 'data_type': 'datetime64[ns]'}], 'film_category': [{'column_name': 'film_id', 'data_type': 'int64'}, {'column_name': 'category_id', 'data_type': 'int64'}, {'column_name': 'last_update', 'data_type': 'datetime64[ns]'}], 'inventory': [{'column_name': 'inventory_id', 'data_type': 'int64'}, {'column_name': 'film_id', 'data_type': 'int64'}, {'column_name': 'store_id', 'data_type': 'int64'}, {'column_name': 'last_update', 'data_type': 'datetime64[ns]'}], 'language': [{'column_name': 'language_id', 'data_type': 'int64'}, {'column_name': 'last_update', 'data_type': 'datetime64[ns]'}, {'column_name': 'name', 'data_type': 'object'}], 'rental': [{'column_name': 'rental_id', 'data_type': 'int64'}, {'column_name': 'rental_date', 'data_type': 'datetime64[ns]'}, {'column_name': 'inventory_id', 'data_type': 'int64'}, {'column_name': 'customer_id', 'data_type': 'int64'}, {'column_name': 'return_date', 'data_type': 'datetime64[ns]'}, {'column_name': 'staff_id', 'data_type': 'int64'}, {'column_name': 'last_update', 'data_type': 'datetime64[ns]'}], 'staff': [{'column_name': 'picture', 'data_type': 'object'}, {'column_name': 'address_id', 'data_type': 'int64'}, {'column_name': 'store_id', 'data_type': 'int64'}, {'column_name': 'active', 'data_type': 'bool'}, {'column_name': 'last_update', 'data_type': 'datetime64[ns]'}, {'column_name': 'staff_id', 'data_type': 'int64'}, {'column_name': 'first_name', 'data_type': 'object'}, {'column_name': 'last_name', 'data_type': 'object'}, {'column_name': 'password', 'data_type': 'object'}, {'column_name': 'email', 'data_type': 'object'}, {'column_name': 'username', 'data_type': 'object'}], 'payment': [{'column_name': 'payment_id', 'data_type': 'int64'}, {'column_name': 'customer_id', 'data_type': 'int64'}, {'column_name': 'staff_id', 'data_type': 'int64'}, {'co ...

# %% [markdown]
# ## 2. Extract

# %% [markdown]
# ### 2.1. Extract From Data Source I

# %% [markdown]
# - Lakukan ekstrak data dari Data Source I
# - Simpan dataframenya dengan nama `city_df`

# %%
# Your code here
# Read data
...
city_df = pd.read_csv(city_raw)
# Tampilkan 5 data teratas
...
city_df.head(5)
# Out:
#    city_id                city               country
# 0        1  A Corua (La Corua)                 Spain
# 1        2                Abha          Saudi Arabia
# 2        3           Abu Dhabi  United Arab Emirates
# 3        4                Acua                Mexico
# 4        5               Adana                Turkey

# %% [markdown]
# ### 2.2. Extract From Data Source II

# %% [markdown]
# - Lakukan ekstrak data dari Data Source II
# - Simpan dataframenya dengan nama `country_df`

# %%
# Your code here
# Read data
...
country_df = pd.read_csv(country_raw)
# Tampilkan 5 data teratas
...

country_df.head()
# Out:
#           country          last_update
# 0     Afghanistan  2006-02-15 09:44:00
# 1         Algeria  2006-02-15 09:44:00
# 2  American Samoa  2006-02-15 09:44:00
# 3          Angola  2006-02-15 09:44:00
# 4        Anguilla  2006-02-15 09:44:00

# %% [markdown]
# ### 2.3. Extract From Data Source III

# %% [markdown]
# - Buatlah function untuk mendapatkan tabel pada database
# - Parameter :
#     - nama tabel
#     - engine koneksi ke database
# - Return : dataframe

# %%
# Your code here
# Buat fungsi untuk mendapatkan tabel pada database
...
def get_table_data(name, eng):
    try:
        query = f'SELECT * FROM {name}'
        df = pd.read_sql(query, eng)

        return df
    except Exception as e:
        print(f"error = {e}")

        return pd.DataFrame()

# %% [markdown]
# - Buat masing-masing dataframe untuk setiap table tersebut

# %%
actor_df = get_table_data('actor', engine)
store_df = get_table_data('store', engine)
address_df = get_table_data('address', engine)
category_df = get_table_data('category', engine)
customer_df = get_table_data('customer', engine)
film_actor_df = get_table_data('film_actor', engine)
film_category_df = get_table_data('film_category', engine)
inventory_df = get_table_data('inventory',engine)
language_df = get_table_data('language',engine)
rental_df = get_table_data('rental',engine)
staff_df = get_table_data('staff',engine)
payment_df = get_table_data('payment',engine)
film_df = get_table_data('film',engine)

# %% [markdown]
# - Rampung semua dataframe dari Data Source 1, 2, dan 3 ke dalam sebuah **Dictionary**.
# - Keys:
#     - nama tabel
# - Value:
#     - dataframe

# %%
# Your code here
...

table_dict = {
#source 1
'city' : city_df,

#source 2
'country' : country_df,

#source 3
'actor' : actor_df, 
'store': store_df, 
'address' : address_df, 
'category' : category_df, 
'customer' : customer_df, 
'film_actor' : film_actor_df, 
'film_category' : film_category_df, 
'inventory' : inventory_df,
'language' : language_df,
'rental' : rental_df,
'staff' : staff_df,
'payment' : payment_df,
'film' : film_df
}

# %% [markdown]
# ## 3. Data Validations

# %% [markdown]
# - Pada bagian ini akan dilakukan beberapa **pengecekan**, yaitu :
#     - Check `Table Requirements`
#     - Check Data `Shape`
#     - Check `Columns`
#     - Check Data `Types`
#     - Check `Missing Values`
#     - Check `Duplicates Data`

# %% [markdown]
# ### 3.1. Check `Table Requirements`

# %% [markdown]
# - Pada bagian ini kita akan melakukan **pengecekan daftar tabel**.
# - Pengecekan dilakukan pada :
#     - Data Source I
#     - Data Source II
#     - Data Source III
# - Pastikan tabel yang dimiliki dari data source sesuai dengan requirements table.

# %% [markdown]
# - Buat fungsi pengecekan Tabel : **check_table_requirements**
# - Fungsi ini akan :
#     - Memprint tabulate dengan header nama tabel dan hasil pengecekan tabel tersebut. ✓ jika tabelnya ada dan ✗ jika tabelnya tidak ada
# - Parameter :
#     - actual_table : Dictionary actual table (Data source 1, 2, 3)
#     - requirements_table : Requirements JSON
# - Return : None

# %%
# Your code here
...

def check_table_requirements(actual_table, requirements_table):
    print("STEP 1")

    actual_name = [table_name for table_name in actual_table]
    requirements_table_name = list(requirements_table.keys())
    is_exist = []

    for name in requirements_table_name:

        if name in actual_name:
            is_exist.append([name,'✓'])
        else:
            is_exist.append([name,'✗'])

    headerz = ['Table Name', "Is Exist"]
    table = tabulate(is_exist, headers=headerz, tablefmt="grid")
    print(table)

# %%
check_table_requirements(actual_table = table_dict, 
                         requirements_table = requirements_table)
# Out:
# STEP 1
# +---------------+------------+
# | Table Name    | Is Exist   |
# +===============+============+
# | actor         | ✓          |
# +---------------+------------+
# | store         | ✓          |
# +---------------+------------+
# | address       | ✓          |
# +---------------+------------+
# | category      | ✓          |
# +---------------+------------+
# | city          | ✓          |
# +---------------+------------+
# | country       | ✓          |
# +---------------+------------+
# | customer      | ✓          |
# +---------------+------------+
# | film_actor    | ✓          |
# +---------------+------------+
# | film_category | ✓          |
# +---------------+------------+
# | inventory     | ✓          |
# +---------------+------------+
# | language      | ✓          |
# +---------------+------------+
# | rental        | ✓          |
# +---------------+------------+
# | staff         | ✓          |
# +---------------+------------+
# | payment       | ✓          |
# +---------------+------------+
# | film          | ✓          |
# +---------------+------------+

# %%
check_table_requirements(actual_table = table_dict, 
                         requirements_table = requirements_table)
# Out:
# STEP 1
# +---------------+------------+
# | Table Name    | Is Exist   |
# +===============+============+
# | actor         | ✓          |
# +---------------+------------+
# | store         | ✓          |
# +---------------+------------+
# | address       | ✓          |
# +---------------+------------+
# | category      | ✓          |
# +---------------+------------+
# | city          | ✓          |
# +---------------+------------+
# | country       | ✓          |
# +---------------+------------+
# | customer      | ✓          |
# +---------------+------------+
# | film_actor    | ✓          |
# +---------------+------------+
# | film_category | ✓          |
# +---------------+------------+
# | inventory     | ✓          |
# +---------------+------------+
# | language      | ✓          |
# +---------------+------------+
# | rental        | ✓          |
# +---------------+------------+
# | staff         | ✓          |
# +---------------+------------+
# | payment       | ✓          |
# +---------------+------------+
# | film          | ✓          |
# +---------------+------------+

# %% [markdown]
# ### 3.2. Check `Data Shape`

# %% [markdown]
# - Buat fungsi pengecekan data shape : **check_shape**
# - Fungsi ini akan :
#     - Memprint tabulate untuk menampilkan jumlah baris dan jumlah kolom dari setiap table.
# - Parameter :
#     - actual_table : Dictionary actual table (Data source 1, 2, 3)
#     - requirements_table : Requirements JSON
# - Return : None

# %%
# Your code here
...

def check_shape(actual_table):

    print("STEP 2")


    data_shape = []

    for table in actual_table:

        data_shape.append([table, actual_table[table].shape[0], actual_table[table].shape[1]] )


    head = ['Table_name', 'num of rows','num of column']
    table = tabulate(data_shape, headers=head, tablefmt="grid")

    print(table)

# %%
check_shape(actual_table = table_dict)
# Out:
# STEP 2
# +---------------+---------------+-----------------+
# | Table_name    |   num of rows |   num of column |
# +===============+===============+=================+
# | city          |           677 |               3 |
# +---------------+---------------+-----------------+
# | country       |           109 |               2 |
# +---------------+---------------+-----------------+
# | actor         |           200 |               4 |
# +---------------+---------------+-----------------+
# | store         |             2 |               4 |
# +---------------+---------------+-----------------+
# | address       |           603 |               8 |
# +---------------+---------------+-----------------+
# | category      |            16 |               3 |
# +---------------+---------------+-----------------+
# | customer      |           599 |              10 |
# +---------------+---------------+-----------------+
# | film_actor    |          5462 |               3 |
# +---------------+---------------+-----------------+
# | film_category |          1000 |               3 |
# +---------------+---------------+-----------------+
# | inventory     |          4581 |               4 |
# +---------------+---------------+-----------------+
# | language      |             6 |               3 |
# +---------------+---------------+-----------------+
# | rental        |         16044 |               7 |
# +---------------+---------------+-----------------+
# | staff         |             2 |              11 |
# +---------------+---------------+-----------------+
# | payment       |         14596 |               6 |
# +---------------+---------------+-----------------+
# | film          |          1000 |              13 |
# +---------------+---------------+-----------------+

# %%
check_shape(actual_table = table_dict)
# Out:
# STEP 2
# +---------------+---------------+-----------------+
# | Table_name    |   num of rows |   num of column |
# +===============+===============+=================+
# | city          |           677 |               3 |
# +---------------+---------------+-----------------+
# | country       |           109 |               2 |
# +---------------+---------------+-----------------+
# | actor         |           200 |               4 |
# +---------------+---------------+-----------------+
# | store         |             2 |               4 |
# +---------------+---------------+-----------------+
# | address       |           603 |               8 |
# +---------------+---------------+-----------------+
# | category      |            16 |               3 |
# +---------------+---------------+-----------------+
# | customer      |           599 |              10 |
# +---------------+---------------+-----------------+
# | film_actor    |          5462 |               3 |
# +---------------+---------------+-----------------+
# | film_category |          1000 |               3 |
# +---------------+---------------+-----------------+
# | inventory     |          4581 |               4 |
# +---------------+---------------+-----------------+
# | language      |             6 |               3 |
# +---------------+---------------+-----------------+
# | rental        |         16044 |               7 |
# +---------------+---------------+-----------------+
# | staff         |             2 |              11 |
# +---------------+---------------+-----------------+
# | payment       |         14596 |               6 |
# +---------------+---------------+-----------------+
# | film          |          1000 |              13 |
# +---------------+---------------+-----------------+

# %% [markdown]
# ### 3.3. Check `Columns`

# %% [markdown]
# - Buat fungsi pengecekan nama-nama kolom pada setiap tabel : **check_columns**
# - Fungsi ini akan :
#     - Memprint tabulate untuk menampilkan tabel-tabel yang kolomnya tidak sesuai dengan requirements
# - Parameter :
#     - actual_table : Dictionary actual table (Data source 1, 2, 3)
#     - requirements_table : Requirements JSON
# - Return : None

# %%
# Your code here
...

def check_columns(actual_table, requirements_table):

    for table in requirements_table:

        checking_table = []

        print(f'Table : {table}')

        act_table_column = actual_table[table].columns.tolist()

        req_table_column = [item['column_name'] for item in requirements_table[table]]

        set_all = set(act_table_column) | set(req_table_column)

        for column_name in set_all:

            if column_name in act_table_column and column_name in req_table_column:
                checking_table.append([column_name, '✓', '✓'])
            elif column_name in act_table_column and column_name not in req_table_column:
                checking_table.append([column_name, '✓', '✗'])
            elif column_name not in act_table_column and column_name in req_table_column:
                checking_table.append([column_name, '✗', '✓'])
            
        headerz = ['Column Name', "Is Exist in Actual Table", "Is Exist in Requirements Table"]
        table = tabulate(checking_table, headers=headerz, tablefmt="grid")
        print(table)
        print("\n\n")
    

            


        # print(actual_table_colu)

# %%
check_columns(actual_table = table_dict,
              requirements_table = requirements_table)
# Out:
# Table : actor
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | first_name    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_name     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | actor_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : store
# +------------------+----------------------------+----------------------------------+
# | Column Name      | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +==================+============================+==================================+
# | address_id       | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | store_id         | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | manager_staff_id | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | last_update      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
#
#
#
# Table : address
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | postal_code   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address2      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | phone         | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | district      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | city_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : category
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | name          | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | category_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : city
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_update   | ✗                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | country_id    | ✗                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | country       | ✓                          | ✗                                |
# +---------------+----------------------------+----------------------------------+
# | city_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | city          | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : country
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | country_id    | ✗                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | country       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : customer
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | active        | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | first_name    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_name     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | store_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | activebool    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | email         | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | create_date   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | customer_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : film_actor
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | film_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | actor_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : film_category
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | film_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | category_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : inventory
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | store_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | film_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | inventory_id  | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : language
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | language_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | name          | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : rental
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | staff_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | rental_id     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | rental_date   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | customer_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | return_date   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | inventory_id  | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : staff
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | active        | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | first_name    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_name     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | store_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | staff_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | password      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | email         | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | username      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | picture       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : payment
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | payment_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | staff_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | rental_id     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | customer_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | payment_date  | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | amount        | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : film
# +------------------+----------------------------+----------------------------------+
# | Column Name      | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +==================+============================+==================================+
# | rental_rate      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | last_update      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | language_id      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | length           | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | title            | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | special_features | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | release_year     | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | fulltext         | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | rating           | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | description      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | replacement_cost | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | rental_duration  | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | film_id          | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+

# %%
check_columns(actual_table = table_dict,
              requirements_table = requirements_table)
# Out:
# Table : actor
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_name     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | first_name    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | actor_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : store
# +------------------+----------------------------+----------------------------------+
# | Column Name      | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +==================+============================+==================================+
# | last_update      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | manager_staff_id | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | store_id         | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | address_id       | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
#
#
#
# Table : address
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address2      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | district      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | city_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | postal_code   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | phone         | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : category
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | name          | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | category_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : city
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | city          | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | city_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | country_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : country
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | country       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | country_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : customer
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_name     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | create_date   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | active        | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | first_name    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | activebool    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | customer_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | store_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | email         | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : film_actor
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | film_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | actor_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : film_category
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | category_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | film_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : inventory
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | store_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | inventory_id  | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | film_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : language
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | name          | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | language_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : rental
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | staff_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | customer_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | return_date   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | inventory_id  | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | rental_id     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | rental_date   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : staff
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_name     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | active        | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | first_name    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | staff_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | password      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | store_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | username      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | email         | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | picture       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : payment
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | staff_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | payment_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | customer_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | payment_date  | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | rental_id     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | amount        | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : film
# +------------------+----------------------------+----------------------------------+
# | Column Name      | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +==================+============================+==================================+
# | rental_duration  | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | last_update      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | description      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | special_features | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | film_id          | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | title            | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | language_id      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | rating           | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | rental_rate      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | fulltext         | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | replacement_cost | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | length           | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | release_year     | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+

# %% [markdown]
# ### 3.4. Check `Data Types`

# %% [markdown]
# - Buat fungsi pengecekan nama-nama kolom pada setiap tabel : **check_data_types**
# - Fungsi ini akan :
#     - Memprint tabulate untuk menampilkan tabel dan kolom yang tipe datanya tidak sesuai dengan requirements
# - Parameter :
#     - actual_table : Dictionary actual table (Data source 1, 2, 3)
#     - requirements_table : Requirements JSON
# - Return : None

# %%
# Your code here
...

def check_data_types(actual_table, requirements_table):
    print("=> STEP 4: Check Data Types")
    summary_data = []

    for table_name, df in actual_table.items():
        if table_name in requirements_table:
            for column_info in requirements_table[table_name]:
                column_name = column_info["column_name"]
                requirements_type = column_info["data_type"]
                
                if column_name in df.columns:
                    actual_type = str(df[column_name].dtype)
                    match = "✔" if actual_type == requirements_type else "✘"
                    summary_data.append([table_name, column_name, actual_type, requirements_type, match])
                else:
                    summary_data.append([table_name, column_name, "N/A", requirements_type, "✘ (Column not found)"])

    headers = ["Table Name", "Column Name", "Actual Type", "Requirements Type", "Match"]

    mismatch_data = [row for row in summary_data if "✘" in row[4]]
    
    if mismatch_data:
        print("\nSummary of Mismatches Data Types:")
        print(tabulate(mismatch_data, headers = headers, tablefmt = "grid"))
    
    else:
        print("All Data Types Match")

# %%
check_data_types(actual_table = table_dict, 
                 requirements_table = requirements_table)
# Out:
# => STEP 4: Check Data Types
#
# Summary of Mismatches Data Types:
# +--------------+---------------+---------------+---------------------+----------------------+
# | Table Name   | Column Name   | Actual Type   | Requirements Type   | Match                |
# +==============+===============+===============+=====================+======================+
# | city         | country_id    | N/A           | int64               | ✘ (Column not found) |
# +--------------+---------------+---------------+---------------------+----------------------+
# | city         | last_update   | N/A           | datetime64[ns]      | ✘ (Column not found) |
# +--------------+---------------+---------------+---------------------+----------------------+
# | country      | country_id    | N/A           | int64               | ✘ (Column not found) |
# +--------------+---------------+---------------+---------------------+----------------------+
# | country      | last_update   | object        | datetime64[ns]      | ✘                    |
# +--------------+---------------+---------------+---------------------+----------------------+
# | customer     | create_date   | object        | datetime64[ns]      | ✘                    |
# +--------------+---------------+---------------+---------------------+----------------------+

# %% [markdown]
# ### 3.5. Check `Missing Values`

# %% [markdown]
# - Buat fungsi pengecekan nama-nama kolom pada setiap tabel : **check_missing_values**
# - Fungsi ini akan :
#     - Memprint tabulate untuk menampilkan tabel dan kolom yang mempunyai missing values.
#     - Menampilkan jumlah dan persentase missing values
# - Parameter :
#     - actual_table : Dictionary actual table (Data source 1, 2, 3)
#     - requirements_table : Requirements JSON
# - Return : None

# %%
# Your code here
...

def check_missing_values(actual_table):

    print("STEP 4")

    missing_value = []

    for table in actual_table:

        num_missing_value = actual_table[table].isna().sum().sum()

        missing_value.append([table, num_missing_value])

    headerz = ['Table Name', 'Num of Missing Value']
    table = tabulate(missing_value, headers=headerz, tablefmt="grid")
    print(table)

# %%
check_missing_values(actual_table = table_dict)
# Out:
# STEP 4
# +---------------+------------------------+
# | Table Name    |   Num of Missing Value |
# +===============+========================+
# | city          |                     17 |
# +---------------+------------------------+
# | country       |                      0 |
# +---------------+------------------------+
# | actor         |                      0 |
# +---------------+------------------------+
# | store         |                      0 |
# +---------------+------------------------+
# | address       |                      4 |
# +---------------+------------------------+
# | category      |                      0 |
# +---------------+------------------------+
# | customer      |                      0 |
# +---------------+------------------------+
# | film_actor    |                      0 |
# +---------------+------------------------+
# | film_category |                      0 |
# +---------------+------------------------+
# | inventory     |                      0 |
# +---------------+------------------------+
# | language      |                      0 |
# +---------------+------------------------+
# | rental        |                    183 |
# +---------------+------------------------+
# | staff         |                      1 |
# +---------------+------------------------+
# | payment       |                      0 |
# +---------------+------------------------+
# | film          |                      0 |
# +---------------+------------------------+

# %% [markdown]
# ### 3.6. Check `Duplicates Data`

# %% [markdown]
# - Buat fungsi pengecekan nama-nama kolom pada setiap tabel : **check_duplicates_data**
# - Fungsi ini akan :
#     - Memprint tabulate untuk menampilkan tabel yang mempunyai data duplikat.
#     - Menampilkan jumlah data yang duplikat (Semua data yang terindikasi duplikat).
# - Parameter :
#     - actual_table : Dictionary actual table (Data source 1, 2, 3)
#     - requirements_table : Requirements JSON
# - Return : None

# %%
# Your code here
...

def check_duplicates_data(table_dict):
    
    print("=> STEP 6: Check Duplicates Data")
    duplicate_summary = []

    for table_name, df in table_dict.items():
        try:
            duplicate_rows = df[df.duplicated(keep = False)]
            
            if not duplicate_rows.empty:
                duplicate_summary.append([table_name, len(duplicate_rows)])
        except:
            pass

    if duplicate_summary:
        print("Duplicate Data Summary:")
        print(tabulate(duplicate_summary, headers=["Table Name", "Duplicate Rows Count"], tablefmt="grid"))
    else:
        print("No Duplicate Data Found")

# %%
check_duplicates_data(table_dict)
# Out:
# => STEP 6: Check Duplicates Data
# Duplicate Data Summary:
# +--------------+------------------------+
# | Table Name   |   Duplicate Rows Count |
# +==============+========================+
# | city         |                    154 |
# +--------------+------------------------+

# %%
check_duplicates_data(table_dict)
# Out:
# => STEP 6: Check Duplicates Data
# Duplicate Data Summary:
# +--------------+------------------------+
# | Table Name   |   Duplicate Rows Count |
# +==============+========================+
# | city         |                    154 |
# +--------------+------------------------+

# %% [markdown]
# ## 4. Data Transform

# %% [markdown]
# - Proses transformasi ini dilakukan untuk **mempersiapkan data untuk diload ke Data Warehouse.**
# - **Pertama, lakukanlah cleaning** sebelum datanya diload ke data warehouse **pada database dvdrental_clean**.
# <center>
#
# <img src="https://sekolahdata-assets.s3.ap-southeast-1.amazonaws.com/notebook-images/mde-intro-to-data-eng/10_01.png"/>
# <center>

# %% [markdown]
# ### 4.1. Data Cleansing

# %% [markdown]
# - Berdasarkan **hasil validations** diketahui bahwa data yang diperoleh dari beberapa data source **masih belum clean.**
#     - **Kolom yang tidak sesuai requirements terdapat pada tabel:**
# 	    - city
# 	    - country
#     - **Terdapat missing values pada kolom :**
# 	    - address
# 	    - city
# 	    - rental
# 	    - staff
#     - **Tipe data yang tidak sesuai requirements terdapat pada tabel :**
# 	    - city
# 	    - country
# 	    - customer
#     - **Terdapat duplicates data pada kolom :**
# 	    - city

# %% [markdown]
# - Oleh karena itu, kita akan bersihkan datanya terlebih dahulu.

# %% [markdown]
# #### 4.1.1. Handle mismatch columns

# %% [markdown]
# **TABLE : country**

# %% [markdown]
# - Berikut adalah **data aktual** dari tabel "country"

# %%
country_df = table_dict['country']
country_df.head()
# Out:
#           country          last_update
# 0     Afghanistan  2006-02-15 09:44:00
# 1         Algeria  2006-02-15 09:44:00
# 2  American Samoa  2006-02-15 09:44:00
# 3          Angola  2006-02-15 09:44:00
# 4        Anguilla  2006-02-15 09:44:00

# %% [markdown]
# - Berikut adalah **requirements** untuk tabel "country"

# %%
requirements_table['country']
# Out:
# [{'column_name': 'country_id', 'data_type': 'int64'},
#  {'column_name': 'last_update', 'data_type': 'datetime64[ns]'},
#  {'column_name': 'country', 'data_type': 'object'}]

# %% [markdown]
# - Pada table country aktual belum mempunyai kolom country_id, maka :
#     - **tambahkan colom country_id.**
# - Ketentuan :
#     - country_id tersebut dimulai dari angka 1 dan seterusnya

# %%
# Your code here
# Menambahkan kolom baru 'country_id' di posisi pertama
...
country_df.insert(0, 'country_id', range(1, len(country_df) + 1))


# Tampilkan 5 data teratas
...
country_df.head()
# Out:
#    country_id         country          last_update
# 0           1     Afghanistan  2006-02-15 09:44:00
# 1           2         Algeria  2006-02-15 09:44:00
# 2           3  American Samoa  2006-02-15 09:44:00
# 3           4          Angola  2006-02-15 09:44:00
# 4           5        Anguilla  2006-02-15 09:44:00

# %% [markdown]
# - **Rubah dataframe country pada table_dict**

# %%
# Your code here
...
table_dict['country'] = country_df

# %% [markdown]
# **TABLE : city**

# %% [markdown]
# - Berikut adalah **data aktual** pada tabel "city".

# %%
city_df = table_dict['city']

city_df.head()
# Out:
#    city_id                city               country
# 0        1  A Corua (La Corua)                 Spain
# 1        2                Abha          Saudi Arabia
# 2        3           Abu Dhabi  United Arab Emirates
# 3        4                Acua                Mexico
# 4        5               Adana                Turkey

# %% [markdown]
# - Berikut adalah **requirements** untuk table "city".

# %%
requirements_table['city']
# Out:
# [{'column_name': 'city_id', 'data_type': 'int64'},
#  {'column_name': 'country_id', 'data_type': 'int64'},
#  {'column_name': 'last_update', 'data_type': 'datetime64[ns]'},
#  {'column_name': 'city', 'data_type': 'object'}]

# %% [markdown]
# - Pada tabel city :
#     - **Buat kolom :**
#         - country_id
#         - last_update
#     - **Hapus kolom :**
#         - country
# - Untuk mencapai tujuan tersebut, lakukan **merge dengan table country** untuk **mendapatkan data country_id dan last_update**.

# %%
# Your code here
...

temp_df = city_df.merge(country_df, left_on='country', right_on='country', how='left')

city_df = temp_df[['city_id', 'city', 'country_id',  'last_update']]

city_df.head()
# Out:
#    city_id                city  country_id          last_update
# 0        1  A Corua (La Corua)        87.0  2006-02-15 09:44:00
# 1        2                Abha        82.0  2006-02-15 09:44:00
# 2        3           Abu Dhabi       101.0  2006-02-15 09:44:00
# 3        4                Acua        60.0  2006-02-15 09:44:00
# 4        5               Adana        97.0  2006-02-15 09:44:00

# %% [markdown]
# - **Rubah dataframe city pada table_dict**

# %%
# Your code here
...
table_dict['city'] = city_df

# %% [markdown]
# - Setelah menyesuaikan kolom pada data aktual dengan requirements, **validasi** kolomnya kembali. Gunakan fungsi `check_columns`

# %%
check_columns(actual_table = table_dict,
              requirements_table = requirements_table)
# Out:
# Table : actor
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | first_name    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_name     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | actor_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : store
# +------------------+----------------------------+----------------------------------+
# | Column Name      | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +==================+============================+==================================+
# | address_id       | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | store_id         | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | manager_staff_id | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | last_update      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
#
#
#
# Table : address
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | postal_code   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address2      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | phone         | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | district      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | city_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : category
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | name          | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | category_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : city
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | country_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | city          | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | city_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : country
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | country_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | country       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : customer
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | active        | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | first_name    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_name     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | store_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | activebool    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | email         | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | create_date   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | customer_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : film_actor
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | film_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | actor_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : film_category
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | film_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | category_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : inventory
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | store_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | film_id       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | inventory_id  | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : language
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | language_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | name          | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : rental
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | staff_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | rental_id     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | rental_date   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | customer_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | return_date   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | inventory_id  | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : staff
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | active        | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | first_name    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_name     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | store_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | staff_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | password      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | email         | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | username      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | last_update   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | picture       | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | address_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : payment
# +---------------+----------------------------+----------------------------------+
# | Column Name   | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +===============+============================+==================================+
# | payment_id    | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | staff_id      | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | rental_id     | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | customer_id   | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | payment_date  | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
# | amount        | ✓                          | ✓                                |
# +---------------+----------------------------+----------------------------------+
#
#
#
# Table : film
# +------------------+----------------------------+----------------------------------+
# | Column Name      | Is Exist in Actual Table   | Is Exist in Requirements Table   |
# +==================+============================+==================================+
# | rental_rate      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | last_update      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | language_id      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | length           | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | title            | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | special_features | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | release_year     | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | fulltext         | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | rating           | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | description      | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | replacement_cost | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | rental_duration  | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+
# | film_id          | ✓                          | ✓                                |
# +------------------+----------------------------+----------------------------------+

# %% [markdown]
# - Hal tersebut menunjukkan kolom-kolom pada data aktual sudah sesuai dengan requirements.

# %% [markdown]
# #### 4.1.2. Handle Missing Values

# %% [markdown]
# - Pada proses handle missing values ini akan dilakukan dropping missing values

# %% [markdown]
# - **Buatlah fungsi** untuk remove missing values : **remove_missing_values**
# - Fungsi ini akan :
#     - Menghapus missing values pada setiap tabel.
# - Parameter :
#     - actual_table : Dictionary actual table (Data source 1, 2, 3)
# - Return :
#     - cleaned_actual_table : Dictionary actual table yang sudah bersih dari missing values

# %%
# Your code here
...
def remove_missing_values(actual_table):

    for table in actual_table:

        actual_table[table] = actual_table[table].dropna()

    return actual_table

# %% [markdown]
# - Update table_dict dengan data yang sudah tidak mempunyai missing values

# %%
# Your code here
...

cleaned_table_dict = remove_missing_values(table_dict)

# %% [markdown]
# - Validasi missing valuenya kembali. Gunakan fungsi **check_missing_values**

# %%
check_missing_values(actual_table = cleaned_table_dict)
# Out:
# STEP 4
# +---------------+------------------------+
# | Table Name    |   Num of Missing Value |
# +===============+========================+
# | city          |                      0 |
# +---------------+------------------------+
# | country       |                      0 |
# +---------------+------------------------+
# | actor         |                      0 |
# +---------------+------------------------+
# | store         |                      0 |
# +---------------+------------------------+
# | address       |                      0 |
# +---------------+------------------------+
# | category      |                      0 |
# +---------------+------------------------+
# | customer      |                      0 |
# +---------------+------------------------+
# | film_actor    |                      0 |
# +---------------+------------------------+
# | film_category |                      0 |
# +---------------+------------------------+
# | inventory     |                      0 |
# +---------------+------------------------+
# | language      |                      0 |
# +---------------+------------------------+
# | rental        |                      0 |
# +---------------+------------------------+
# | staff         |                      0 |
# +---------------+------------------------+
# | payment       |                      0 |
# +---------------+------------------------+
# | film          |                      0 |
# +---------------+------------------------+

# %% [markdown]
# - Dapat dilihat bahwa missing values sudah terhandle.

# %% [markdown]
# #### 4.1.3. Handle Data Types

# %% [markdown]
# - Pada proses handle data types akan dilakukan **casting tipe data** berdasarkan requirements yang telah diberikan.

# %% [markdown]
# - **Buatlah fungsi** untuk menghandle Data Types : **adjust_data_types**
# - Fungsi ini akan :
#     - Melakukan casting tipe data sesuai dengan requirements.
# - Parameter :
#     - actual_table : Dictionary actual table (Data source 1, 2, 3)
# - Return :
#     - cleaned_actual_table : Dictionary actual table yang sudah bersih dari missing values

# %%
# Your code here
...

def adjust_data_types(actual_table, requirements_table):
    print("=> STEP 7: Adjust Data Types")
    for table_name, df in actual_table.items():
        if table_name in requirements_table:
            for column_info in requirements_table[table_name]:
                column_name = column_info["column_name"]
                requirements_type = column_info["data_type"]
                
                if column_name in df.columns:
                    try:
                        if requirements_type == "int64":
                            actual_table[table_name][column_name] = actual_table[table_name][column_name].astype('int64')
                        elif requirements_type == "float64":
                            actual_table[table_name][column_name] = actual_table[table_name][column_name].astype('float64')
                        elif requirements_type == "object":
                            actual_table[table_name][column_name] = actual_table[table_name][column_name].astype('object')
                        elif requirements_type == "datetime64[ns]":
                            actual_table[table_name][column_name] = pd.to_datetime(actual_table[table_name][column_name])
                    except Exception as e:
                        print(f"Error converting {table_name}.{column_name} to {requirements_type}: {e}")

# %% [markdown]
# - Update table_dict dengan data yang sudah sesuai tipe datanya

# %%
# Your code here
...
cleaned_table_dict = adjust_data_types(cleaned_table_dict, requirements_table)
# Out:
# => STEP 7: Adjust Data Types

# %% [markdown]
# - Validasi tipe data dari kolom pada setiap tabel. Gunakan fungsi **check_data_types**

# %%
check_data_types(actual_table =table_dict, 
                 requirements_table = requirements_table)
# Out:
# => STEP 4: Check Data Types
# All Data Types Match

# %% [markdown]
# - Dapat dilihat bahwa tipe data pada data aktual sudah sesuai.

# %% [markdown]
# #### 4.1.4. Handle Duplicates Data

# %% [markdown]
# - Pada proses handling data yang duplikat, akan dilakukan **drop data yang duplikat dengan mempertahankan record data yang pertama**.

# %% [markdown]
# - Buatlah fungsi untuk menghandle Data Types : **remove_duplicates**
# - Fungsi ini akan :
#     - Melakukan drop data yang duplikat dengan mempertahankan record data yang pertama.
# - Parameter :
#     - actual_table : Dictionary actual table (Data source 1, 2, 3)
# - Return :
#     - cleaned_table_dict : Dictionary actual table yang sudah bersih dari missing values

# %%
# Your code here
...
def remove_duplicates_data(table_dict):
    print("=> STEP 8: Remove Duplicates Data")
    for table_name, df in table_dict.items():
        print(f"Processing table: {table_name} with {len(df)} rows before removing duplicates.")
        table_dict[table_name] = df.drop_duplicates()

# %% [markdown]
# - Update table_dict dengan data yang sudah tidak mempunyai data duplikat

# %%
# Your code here
...
table_dict = remove_duplicates_data(table_dict)
# Out:
# => STEP 8: Remove Duplicates Data
# Processing table: city with 594 rows before removing duplicates.
# Processing table: country with 109 rows before removing duplicates.
# Processing table: actor with 200 rows before removing duplicates.
# Processing table: store with 2 rows before removing duplicates.
# Processing table: address with 599 rows before removing duplicates.
# Processing table: category with 16 rows before removing duplicates.
# Processing table: customer with 599 rows before removing duplicates.
# Processing table: film_actor with 5462 rows before removing duplicates.
# Processing table: film_category with 1000 rows before removing duplicates.
# Processing table: inventory with 4581 rows before removing duplicates.
# Processing table: language with 6 rows before removing duplicates.
# Processing table: rental with 15861 rows before removing duplicates.
# Processing table: staff with 1 rows before removing duplicates.
# Processing table: payment with 14596 rows before removing duplicates.
# Processing table: film with 1000 rows before removing duplicates.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 3
#       1 # Your code here
# ----> 3 table_dict = remove_duplicates_data(table_dict)
#
# Cell In[47], line 7, in remove_duplicates_data(table_dict)
#       5 for table_name, df in table_dict.items():
#       6     print(f"Processing table: {table_name} with {len(df)} rows before removing duplicates.")
# ----> 7     table_dict[table_name] = df.drop_duplicates()
#
# File c:\Users\syari\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:6840, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6837 inplace = validate_bool_kwarg(inplace, "inplace")
#    6838 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6840 result = self[-self.duplicated(subset, keep=keep)]
#    6841 if ignore_index:
#    6842     result.index = default_index(len(result))
#
# File c:\Users\syari\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:6980, in DataFrame.duplicated(self, subset, keep)
#    6978 else:
#    6979     vals = (col.values for name, col in self.items() if name in subset)
# -> 6980     labels, shape = map(list, zip(*map(f, vals)))
#    6982     ids = get_group_index(labels, tuple(shape), sort=False, xnull=False)
#    6983     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File c:\Users\syari\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:6948, in DataFrame.duplicated.<locals>.f(vals)
#    6947 def f(vals) -> tuple[np.ndarray, int]:
# -> 6948     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6949     return labels.astype("i8", copy=False), len(shape)
#
# File c:\Users\syari\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\algorithms.py:795, in factorize(values, sort, use_na_sentinel, size_hint)
#     792             # Don't modify (potentially user-provided) array
#     793             values = np.where(null_mask, na_value, values)
# --> 795     codes, uniques = factorize_array(
#     796         values,
#     797         use_na_sentinel=use_na_sentinel,
#     798         size_hint=size_hint,
#     799     )
#     801 if sort and len(uniques) > 0:
#     802     uniques, codes = safe_sort(
#     803         uniques,
#     804         codes,
#    (...)    807         verify=False,
#     808     )
#
# File c:\Users\syari\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\algorithms.py:595, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     592 hash_klass, values = _get_hashtable_algo(values)
#     594 table = hash_klass(size_hint or len(values))
# --> 595 uniques, codes = table.factorize(
#     596     values,
#     597     na_sentinel=-1,
#     598     na_value=na_value,
#     599     mask=mask,
#     600     ignore_na=use_na_sentinel,
#     601 )
#     603 # re-cast e.g. i8->dt64/td64, uint8->bool
#     604 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas/_libs/hashtable_class_helper.pxi:7293, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas/_libs/hashtable_class_helper.pxi:7203, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# - Validasi kembali data yang mengalami duplikat. Gunakan fungsi **check_duplicates_data**

# %%
check_duplicates_data(table_dict)
# Out:
# => STEP 6: Check Duplicates Data
# No Duplicate Data Found

# %% [markdown]
# ### 4.2. Data Manipulation & Data Selection

# %% [markdown]
# - Pada bagian ini, kita akan coba **generate sebuah tabel** yang merupakan kombinasi dari beberapa tabel.
# - Kita akan generate tabel `film_list`
# - Tabel tersebut akan disimpan pada database **dvdrental_analysis**
# - Tabel tersebut merupakan **kombinasi tabel :**
#     - `actor`
#     - `film_actor`
#     - `film`
#     - `film_category`
#     - `category`
# <center>
# <img src="https://sekolahdata-assets.s3.ap-southeast-1.amazonaws.com/notebook-images/mde-intro-to-data-eng/10_02.png"/>

# %% [markdown]
# - Kolom-kolom yang akan kita **generate** adalah :
#     - `fid` -> sama dengan film_id
#     - `title` -> Judul film
#     - `description` -> Deskripsi dari film
#     - `category` -> Kategori film
#     - `price` -> Harga film
#     - `length` -> Durasi film
#     - `rating` -> Rating film
#     - `actors` -> Nama-nama aktor film tersebut
#
# <center>
# <img src="https://sekolahdata-assets.s3.ap-southeast-1.amazonaws.com/notebook-images/mde-intro-to-data-eng/10_03.png"/>
# <center>

# %% [markdown]
# - Pertama, **persiapkan dataframe yang diperlukan.**
# - Dapatkan dataframenya dari **table_dict**

# %%
# Your code here
...

# %% [markdown]
# - Gabungkan tabel-tabel yang diperlukan dengan melakukan **merge**.

# %% [markdown]
# - Merge : **Category -> film_category**
# - on : **category_id**
# - Join Type : **left join**
# - Suffixes : ("_x1", "_y1")

# %%
# Your code here
# Buat dataframe "film_list" untuk menyimpan hasil merge
...
film_list_df =  category_df.merge(film_category_df, left_on='category_id', right_on='category_id', how='left', suffixes=('_x1',"_y1"))

# Tampilkan 5 data "film_list" teratas
...
film_list_df.head()
# Out:
#    category_id    name      last_update_x1  film_id      last_update_y1
# 0            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 1            1  Action 2006-02-15 09:46:27       21 2006-02-15 10:07:09
# 2            1  Action 2006-02-15 09:46:27       29 2006-02-15 10:07:09
# 3            1  Action 2006-02-15 09:46:27       38 2006-02-15 10:07:09
# 4            1  Action 2006-02-15 09:46:27       56 2006-02-15 10:07:09

# %% [markdown]
# - Merge : **film_list -> film**
# - on : **film_id**
# - Join Type : **left join**
# - Suffixes : ("_x2", "_y2")

# %%
film_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   film_id           1000 non-null   int64
#  1   title             1000 non-null   object
#  2   description       1000 non-null   object
#  3   release_year      1000 non-null   int64
#  4   language_id       1000 non-null   int64
#  5   rental_duration   1000 non-null   int64
#  6   rental_rate       1000 non-null   float64
#  7   length            1000 non-null   int64
#  8   replacement_cost  1000 non-null   float64
#  9   rating            1000 non-null   object
#  10  last_update       1000 non-null   datetime64[ns]
#  11  special_features  1000 non-null   object
#  12  fulltext          1000 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(5)
# memory usage: 101.7+ KB

# %%
# Your code here
# Update dataframe "film_list" untuk menyimpan hasil merge
...
film_list_df = film_list_df.merge(film_df, left_on='film_id', right_on='film_id', how='left', suffixes=('_x2',"_y2"))

# Tampilkan 5 data "film_list" teratas
...
film_list_df.head()
# Out:
#    category_id    name      last_update_x1  film_id      last_update_y1  \
# 0            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 1            1  Action 2006-02-15 09:46:27       21 2006-02-15 10:07:09
# 2            1  Action 2006-02-15 09:46:27       29 2006-02-15 10:07:09
# 3            1  Action 2006-02-15 09:46:27       38 2006-02-15 10:07:09
# 4            1  Action 2006-02-15 09:46:27       56 2006-02-15 10:07:09
#
#                  title                                        description  \
# 0         Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 1      American Circus  A Insightful Drama of a Girl And a Astronaut w...
# 2   Antitrust Tomatoes  A Fateful Yarn of a Womanizer And a Feminist w...
# 3        Ark Ridgemont  A Beautiful Yarn of a Pioneer And a Monkey who...
# 4  Barefoot Manchurian  A Intrepid Story of a Cat And a Student who mu...
#
#    release_year  language_id  rental_duration  rental_rate  length  \
# 0          2006            1                6         0.99     113
# 1          2006            1                3         4.99     129
# 2          2006            1                5         2.99     168
# 3          2006            1                6         0.99      68
# 4          2006            1                6         2.99     129
#
#    replacement_cost rating             last_update  \
# 0             20.99     PG 2013-05-26 14:50:58.951
# 1             17.99      R 2013-05-26 14:50:58.951
# 2             11.99  NC-17 2013-05-26 14:50:58.951
# 3             25.99  NC-17 2013-05-26 14:50:58.951
# 4             15.99      G 2013-05-26 14:50:58.951
#
#                                     special_features  \
# 0  [Commentaries, Deleted Scenes, Behind the Scenes]
# 1                  [Commentaries, Behind the Scenes]
# 2           [Trailers, Commentaries, Deleted Scenes]
# 3  [Trailers, Commentaries, Deleted Scenes, Behin...
# 4                           [Trailers, Commentaries]
#
#                                             fulltext
# 0  'amadeus':1 'baloon':20 'battl':15 'display':5...
# 1  'administr':17 'american':1 'astronaut':11 'ci...
# 2  'administr':17 'ancient':19 'antitrust':1 'dat...
# 3  'ark':1 'beauti':4 'desert':20 'explor':16 'mo...
# 4  'abandon':19 'amus':20 'barefoot':1 'cat':8 'g...

# %%
# Your code here
# Update dataframe "film_list" untuk menyimpan hasil merge
...
film_list_df = film_list_df.merge(film_df, left_on='film_id', right_on='film_id', how='left', suffixes=('_x2',"_y2"))

# Tampilkan 5 data "film_list" teratas
...
film_list_df.head()
# Out:
#    category_id    name      last_update_x1  film_id      last_update_y1  \
# 0            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 1            1  Action 2006-02-15 09:46:27       21 2006-02-15 10:07:09
# 2            1  Action 2006-02-15 09:46:27       29 2006-02-15 10:07:09
# 3            1  Action 2006-02-15 09:46:27       38 2006-02-15 10:07:09
# 4            1  Action 2006-02-15 09:46:27       56 2006-02-15 10:07:09
#
#                  title                                        description  \
# 0         Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 1      American Circus  A Insightful Drama of a Girl And a Astronaut w...
# 2   Antitrust Tomatoes  A Fateful Yarn of a Womanizer And a Feminist w...
# 3        Ark Ridgemont  A Beautiful Yarn of a Pioneer And a Monkey who...
# 4  Barefoot Manchurian  A Intrepid Story of a Cat And a Student who mu...
#
#    release_year  language_id  rental_duration  rental_rate  length  \
# 0          2006            1                6         0.99     113
# 1          2006            1                3         4.99     129
# 2          2006            1                5         2.99     168
# 3          2006            1                6         0.99      68
# 4          2006            1                6         2.99     129
#
#    replacement_cost rating             last_update  \
# 0             20.99     PG 2013-05-26 14:50:58.951
# 1             17.99      R 2013-05-26 14:50:58.951
# 2             11.99  NC-17 2013-05-26 14:50:58.951
# 3             25.99  NC-17 2013-05-26 14:50:58.951
# 4             15.99      G 2013-05-26 14:50:58.951
#
#                                     special_features  \
# 0  [Commentaries, Deleted Scenes, Behind the Scenes]
# 1                  [Commentaries, Behind the Scenes]
# 2           [Trailers, Commentaries, Deleted Scenes]
# 3  [Trailers, Commentaries, Deleted Scenes, Behin...
# 4                           [Trailers, Commentaries]
#
#                                             fulltext
# 0  'amadeus':1 'baloon':20 'battl':15 'display':5...
# 1  'administr':17 'american':1 'astronaut':11 'ci...
# 2  'administr':17 'ancient':19 'antitrust':1 'dat...
# 3  'ark':1 'beauti':4 'desert':20 'explor':16 'mo...
# 4  'abandon':19 'amus':20 'barefoot':1 'cat':8 'g...

# %% [markdown]
# - Merge : **film_list -> film_actor**
# - on : **film_id**
# - Join Type : **inner join**
# - Suffixes : ("_x3", "_y3")

# %%
# Your code here
# Update dataframe "film_list" untuk menyimpan hasil merge
...
film_list_df = film_list_df.merge(film_actor_df, left_on='film_id', right_on='film_id', how='inner', suffixes=('_x3',"_y3"))

# Tampilkan 5 data "film_list" teratas
...
film_list_df.head()
# Out:
#    category_id    name      last_update_x1  film_id      last_update_y1  \
# 0            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 1            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 2            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 3            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 4            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
#
#           title                                        description  \
# 0  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 1  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 2  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 3  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 4  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
#
#    release_year  language_id  rental_duration  rental_rate  length  \
# 0          2006            1                6         0.99     113
# 1          2006            1                6         0.99     113
# 2          2006            1                6         0.99     113
# 3          2006            1                6         0.99     113
# 4          2006            1                6         0.99     113
#
#    replacement_cost rating          last_update_x3  \
# 0             20.99     PG 2013-05-26 14:50:58.951
# 1             20.99     PG 2013-05-26 14:50:58.951
# 2             20.99     PG 2013-05-26 14:50:58.951
# 3             20.99     PG 2013-05-26 14:50:58.951
# 4             20.99     PG 2013-05-26 14:50:58.951
#
#                                     special_features  \
# 0  [Commentaries, Deleted Scenes, Behind the Scenes]
# 1  [Commentaries, Deleted Scenes, Behind the Scenes]
# 2  [Commentaries, Deleted Scenes, Behind the Scenes]
# 3  [Commentaries, Deleted Scenes, Behind the Scenes]
# 4  [Commentaries, Deleted Scenes, Behind the Scenes]
#
#                                             fulltext  actor_id  \
# 0  'amadeus':1 'baloon':20 'battl':15 'display':5...         5
# 1  'amadeus':1 'baloon':20 'battl':15 'display':5...        27
# 2  'amadeus':1 'baloon':20 'battl':15 'display':5...        37
# 3  'amadeus':1 'baloon':20 'battl':15 'display':5...        43
# 4  'amadeus':1 'baloon':20 'battl':15 'display':5...        84
#
#        last_update_y3
# 0 2006-02-15 10:05:03
# 1 2006-02-15 10:05:03
# 2 2006-02-15 10:05:03
# 3 2006-02-15 10:05:03
# 4 2006-02-15 10:05:03

# %%
# Your code here
# Update dataframe "film_list" untuk menyimpan hasil merge
...
film_list_df = film_list_df.merge(film_actor_df, left_on='film_id', right_on='film_id', how='inner', suffixes=('_x3',"_y3"))

# Tampilkan 5 data "film_list" teratas
...
film_list_df.head()
# Out:
#    category_id    name      last_update_x1  film_id      last_update_y1  \
# 0            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 1            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 2            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 3            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 4            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
#
#           title                                        description  \
# 0  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 1  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 2  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 3  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 4  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
#
#    release_year  language_id  rental_duration  rental_rate  length  \
# 0          2006            1                6         0.99     113
# 1          2006            1                6         0.99     113
# 2          2006            1                6         0.99     113
# 3          2006            1                6         0.99     113
# 4          2006            1                6         0.99     113
#
#    replacement_cost rating          last_update_x3  \
# 0             20.99     PG 2013-05-26 14:50:58.951
# 1             20.99     PG 2013-05-26 14:50:58.951
# 2             20.99     PG 2013-05-26 14:50:58.951
# 3             20.99     PG 2013-05-26 14:50:58.951
# 4             20.99     PG 2013-05-26 14:50:58.951
#
#                                     special_features  \
# 0  [Commentaries, Deleted Scenes, Behind the Scenes]
# 1  [Commentaries, Deleted Scenes, Behind the Scenes]
# 2  [Commentaries, Deleted Scenes, Behind the Scenes]
# 3  [Commentaries, Deleted Scenes, Behind the Scenes]
# 4  [Commentaries, Deleted Scenes, Behind the Scenes]
#
#                                             fulltext  actor_id  \
# 0  'amadeus':1 'baloon':20 'battl':15 'display':5...         5
# 1  'amadeus':1 'baloon':20 'battl':15 'display':5...        27
# 2  'amadeus':1 'baloon':20 'battl':15 'display':5...        37
# 3  'amadeus':1 'baloon':20 'battl':15 'display':5...        43
# 4  'amadeus':1 'baloon':20 'battl':15 'display':5...        84
#
#        last_update_y3
# 0 2006-02-15 10:05:03
# 1 2006-02-15 10:05:03
# 2 2006-02-15 10:05:03
# 3 2006-02-15 10:05:03
# 4 2006-02-15 10:05:03

# %% [markdown]
# - Merge : **film_list -> actor**
# - on : **actor_id**
# - Join Type : **inner join**
# - Suffixes : ("_x4", "_y4")

# %%
# Your code here
# Update dataframe "film_list" untuk menyimpan hasil merge
...
film_list_df = film_list_df.merge(actor_df, left_on='actor_id', right_on='actor_id', how='inner', suffixes=('_x4',"_y4"))

# Tampilkan 5 data "film_list" teratas
...
film_list_df.head()
# Out:
#    category_id    name      last_update_x1  film_id      last_update_y1  \
# 0            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 1            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 2            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 3            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 4            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
#
#           title                                        description  \
# 0  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 1  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 2  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 3  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 4  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
#
#    release_year  language_id  rental_duration  ...  replacement_cost  rating  \
# 0          2006            1                6  ...             20.99      PG
# 1          2006            1                6  ...             20.99      PG
# 2          2006            1                6  ...             20.99      PG
# 3          2006            1                6  ...             20.99      PG
# 4          2006            1                6  ...             20.99      PG
#
#            last_update_x3                                   special_features  \
# 0 2013-05-26 14:50:58.951  [Commentaries, Deleted Scenes, Behind the Scenes]
# 1 2013-05-26 14:50:58.951  [Commentaries, Deleted Scenes, Behind the Scenes]
# 2 2013-05-26 14:50:58.951  [Commentaries, Deleted Scenes, Behind the Scenes]
# 3 2013-05-26 14:50:58.951  [Commentaries, Deleted Scenes, Behind the Scenes]
# 4 2013-05-26 14:50:58.951  [Commentaries, Deleted Scenes, Behind the Scenes]
#
#                                             fulltext actor_id  \
# 0  'amadeus':1 'baloon':20 'battl':15 'display':5...        5
# 1  'amadeus':1 'baloon':20 'battl':15 'display':5...       27
# 2  'amadeus':1 'baloon':20 'battl':15 'display':5...       37
# 3  'amadeus':1 'baloon':20 'battl':15 'display':5...       43
# 4  'amadeus':1 'baloon':20 'battl':15 'display':5...       84
#
#        last_update_y3  first_name     last_name             last_update
# 0 2006-02-15 10:05:03      Johnny  Lollobrigida 2013-05-26 14:47:57.620
# 1 2006-02-15 10:05:03       Julia       Mcqueen 2013-05-26 14:47:57.620
# 2 2006-02-15 10:05:03         Val        Bolger 2013-05-26 14:47:57.620
# 3 2006-02-15 10:05:03        Kirk      Jovovich 2013-05-26 14:47:57.620
# 4 2006-02-15 10:05:03       James          Pitt 2013-05-26 14:47:57.620
#
# [5 rows x 22 columns]

# %%
# Your code here
# Update dataframe "film_list" untuk menyimpan hasil merge
...
film_list_df = film_list_df.merge(actor_df, left_on='actor_id', right_on='actor_id', how='inner', suffixes=('_x4',"_y4"))

# Tampilkan 5 data "film_list" teratas
...
film_list_df.head()
# Out:
#    category_id    name      last_update_x1  film_id      last_update_y1  \
# 0            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 1            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 2            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 3            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
# 4            1  Action 2006-02-15 09:46:27       19 2006-02-15 10:07:09
#
#           title                                        description  \
# 0  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 1  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 2  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 3  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
# 4  Amadeus Holy  A Emotional Display of a Pioneer And a Technic...
#
#    release_year  language_id  rental_duration  ...  replacement_cost  rating  \
# 0          2006            1                6  ...             20.99      PG
# 1          2006            1                6  ...             20.99      PG
# 2          2006            1                6  ...             20.99      PG
# 3          2006            1                6  ...             20.99      PG
# 4          2006            1                6  ...             20.99      PG
#
#            last_update_x3                                   special_features  \
# 0 2013-05-26 14:50:58.951  [Commentaries, Deleted Scenes, Behind the Scenes]
# 1 2013-05-26 14:50:58.951  [Commentaries, Deleted Scenes, Behind the Scenes]
# 2 2013-05-26 14:50:58.951  [Commentaries, Deleted Scenes, Behind the Scenes]
# 3 2013-05-26 14:50:58.951  [Commentaries, Deleted Scenes, Behind the Scenes]
# 4 2013-05-26 14:50:58.951  [Commentaries, Deleted Scenes, Behind the Scenes]
#
#                                             fulltext actor_id  \
# 0  'amadeus':1 'baloon':20 'battl':15 'display':5...        5
# 1  'amadeus':1 'baloon':20 'battl':15 'display':5...       27
# 2  'amadeus':1 'baloon':20 'battl':15 'display':5...       37
# 3  'amadeus':1 'baloon':20 'battl':15 'display':5...       43
# 4  'amadeus':1 'baloon':20 'battl':15 'display':5...       84
#
#        last_update_y3  first_name     last_name             last_update
# 0 2006-02-15 10:05:03      Johnny  Lollobrigida 2013-05-26 14:47:57.620
# 1 2006-02-15 10:05:03       Julia       Mcqueen 2013-05-26 14:47:57.620
# 2 2006-02-15 10:05:03         Val        Bolger 2013-05-26 14:47:57.620
# 3 2006-02-15 10:05:03        Kirk      Jovovich 2013-05-26 14:47:57.620
# 4 2006-02-15 10:05:03       James          Pitt 2013-05-26 14:47:57.620
#
# [5 rows x 22 columns]

# %% [markdown]
# - Selanjutnya, **gabungkan** `first_name` dan `last_name` menjadi `full_name`

# %%
# Gabungkan nama depan dan belakang aktor
...
film_list_df['full_name'] = film_list_df['first_name'] + ' ' + film_list_df['last_name']

# Tampilkan kolom "full_name"
...
film_list_df['full_name'].head()
# Out:
# 0    Johnny Lollobrigida
# 1          Julia Mcqueen
# 2             Val Bolger
# 3          Kirk Jovovich
# 4             James Pitt
# Name: full_name, dtype: object

# %% [markdown]
# - Perlu diketahui bahwa satu film bisa terdiri dari beberapa aktor.
# - Oleh karena itu, **gabung nama-nama aktor tersebut di satu film yang sama**.
# - Contoh :
#     <center>
#     <img src="https://sekolahdata-assets.s3.ap-southeast-1.amazonaws.com/notebook-images/mde-intro-to-data-eng/10_04.png"/>
#     <center>

# %%
film_list_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5462 entries, 0 to 5461
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   category_id       5462 non-null   int64
#  1   name              5462 non-null   object
#  2   last_update_x1    5462 non-null   datetime64[ns]
#  3   film_id           5462 non-null   int64
#  4   last_update_y1    5462 non-null   datetime64[ns]
#  5   title             5462 non-null   object
#  6   description       5462 non-null   object
#  7   release_year      5462 non-null   int64
#  8   language_id       5462 non-null   int64
#  9   rental_duration   5462 non-null   int64
#  10  rental_rate       5462 non-null   float64
#  11  length            5462 non-null   int64
#  12  replacement_cost  5462 non-null   float64
#  13  rating            5462 non-null   object
#  14  last_update_x3    5462 non-null   datetime64[ns]
#  15  special_features  5462 non-null   object
#  16  fulltext          5462 non-null   object
#  17  actor_id          5462 non-null   int64
#  18  last_update_y3    5462 non-null   datetime64[ns]
#  19  first_name        5462 non-null   object
#  20  last_name         5462 non-null   object
#  21  last_update       5462 non-null   datetime64[ns]
#  22  full_name         5462 non-null   object
# dtypes: datetime64[ns](5), float64(2), int64(7), object(9)
# memory usage: 981.6+ KB

# %%
# Your code here
# Gabungkan nama aktor menjadi satu string untuk setiap film
...
film_list_df = film_list_df.groupby(['film_id', 'title', 'description', 'name', 'rental_rate', 'length', 'rating'])['full_name'].apply(lambda x: ', '.join(x))

# Tampilkan 5 data teratas
...
film_list_df.head()
# Out:
# film_id  title             description                                                                                                            name         rental_rate  length  rating
# 1        Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies                       Documentary  0.99         86      PG        Penelope Guiness, Christian Gable, Lucille Tra...
# 2        Ace Goldfinger    A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient China                   Horror       4.99         48      G         Bob Fawcett, Minnie Zellweger, Sean Guiness, C...
# 3        Adaptation Holes  A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory                       Documentary  2.99         50      NC-17     Nick Wahlberg, Bob Fawcett, Cameron Streep, Ra...
# 4        Affair Prejudice  A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank                           Horror       2.99         117     G         Jodie Degeneres, Scarlett Damon, Kenneth Pesci...
# 5        African Egg       A Fast-Paced Documentary of a Pastry Chef And a Dentist who must Pursue a Forensic Psychologist in The Gulf of Mexico  Family       2.99         130     G         Gary Phoenix, Dustin Tautou, Matthew Leigh, Ma...
# Name: full_name, dtype: object

# %% [markdown]
# - Hasil tersebut **masih berupa "series"**
# - Oleh karena itu, **rubah menjadi dataframe**

# %%
# Your code here
# Rubah dari series menjadi dataframe
...
film_list_df = pd.DataFrame(film_list_df).reset_index()

# Tampilkan 5 data teratas
...
film_list_df.head()
# Out:
#    film_id             title  \
# 0        1  Academy Dinosaur
# 1        2    Ace Goldfinger
# 2        3  Adaptation Holes
# 3        4  Affair Prejudice
# 4        5       African Egg
#
#                                          description         name  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...  Documentary
# 1  A Astounding Epistle of a Database Administrat...       Horror
# 2  A Astounding Reflection of a Lumberjack And a ...  Documentary
# 3  A Fanciful Documentary of a Frisbee And a Lumb...       Horror
# 4  A Fast-Paced Documentary of a Pastry Chef And ...       Family
#
#    rental_rate  length rating  \
# 0         0.99      86     PG
# 1         4.99      48      G
# 2         2.99      50  NC-17
# 3         2.99     117      G
# 4         2.99     130      G
#
#                                            full_name
# 0  Penelope Guiness, Christian Gable, Lucille Tra...
# 1  Bob Fawcett, Minnie Zellweger, Sean Guiness, C...
# 2  Nick Wahlberg, Bob Fawcett, Cameron Streep, Ra...
# 3  Jodie Degeneres, Scarlett Damon, Kenneth Pesci...
# 4  Gary Phoenix, Dustin Tautou, Matthew Leigh, Ma...

# %%
film_list_df.columns
# Out:
# Index(['film_id', 'title', 'description', 'name', 'rental_rate', 'length',
#        'rating', 'full_name'],
#       dtype='object')

# %% [markdown]
# - Dapat dilihat, yang berstatus sebagai "kolom" hanya "full_name", selebihnya masih berupa index.
# - Oleh karena itu, lakukan **reset index**

# %%
# Your code here
# Reset index
...
film_list_df = film_list_df.reset_index(drop=True)

# Tampilkan 5 data teratas
...
film_list_df.head()
# Out:
#    film_id             title  \
# 0        1  Academy Dinosaur
# 1        2    Ace Goldfinger
# 2        3  Adaptation Holes
# 3        4  Affair Prejudice
# 4        5       African Egg
#
#                                          description         name  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...  Documentary
# 1  A Astounding Epistle of a Database Administrat...       Horror
# 2  A Astounding Reflection of a Lumberjack And a ...  Documentary
# 3  A Fanciful Documentary of a Frisbee And a Lumb...       Horror
# 4  A Fast-Paced Documentary of a Pastry Chef And ...       Family
#
#    rental_rate  length rating  \
# 0         0.99      86     PG
# 1         4.99      48      G
# 2         2.99      50  NC-17
# 3         2.99     117      G
# 4         2.99     130      G
#
#                                            full_name
# 0  Penelope Guiness, Christian Gable, Lucille Tra...
# 1  Bob Fawcett, Minnie Zellweger, Sean Guiness, C...
# 2  Nick Wahlberg, Bob Fawcett, Cameron Streep, Ra...
# 3  Jodie Degeneres, Scarlett Damon, Kenneth Pesci...
# 4  Gary Phoenix, Dustin Tautou, Matthew Leigh, Ma...

# %% [markdown]
# - Terakhir, **rubah nama kolom**.
#     - `film_id` : `fid`
#     - `name` : `category`
#     - `rental_rate` : `price`
#     - `full_name` : `actors`

# %%
# Your code here
# Buat mapping perubahan nama kolom
...
mapping = {
    'film_id':'fid',
    'name' : 'category',
    'rental_rate': 'price',
    'full_name': 'actors'
}

# %%
# Your code here
# Rubah nama kolom
...
film_list_df = film_list_df.rename(columns=mapping)

# Tampilkan 5 data teratas
...
film_list_df.head()
# Out:
#    fid             title                                        description  \
# 0    1  Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 1    2    Ace Goldfinger  A Astounding Epistle of a Database Administrat...
# 2    3  Adaptation Holes  A Astounding Reflection of a Lumberjack And a ...
# 3    4  Affair Prejudice  A Fanciful Documentary of a Frisbee And a Lumb...
# 4    5       African Egg  A Fast-Paced Documentary of a Pastry Chef And ...
#
#       category  price  length rating  \
# 0  Documentary   0.99      86     PG
# 1       Horror   4.99      48      G
# 2  Documentary   2.99      50  NC-17
# 3       Horror   2.99     117      G
# 4       Family   2.99     130      G
#
#                                               actors
# 0  Penelope Guiness, Christian Gable, Lucille Tra...
# 1  Bob Fawcett, Minnie Zellweger, Sean Guiness, C...
# 2  Nick Wahlberg, Bob Fawcett, Cameron Streep, Ra...
# 3  Jodie Degeneres, Scarlett Damon, Kenneth Pesci...
# 4  Gary Phoenix, Dustin Tautou, Matthew Leigh, Ma...

# %% [markdown]
# ## 5. Load Data To Data Warehouse

# %% [markdown]
# - ***NOTES : Pastikan anda sudah mempersiapkan Data Warehousenya. Silahkan lihat "Live Class Preparation" pada Chapter 9***

# %% [markdown]
# ### 5.1. Setup Connection

# %% [markdown]
# - Buat fungsi untuk membuat engine postgres.
#     - user = "root"
#     - password = "qwerty123"
#     - host = "localhost"
#     - port = "3000"
# - Parameter : Nama database

# %%
# Your code here
...
def dw_postgres_engine(dbname):

    user = 'root'
    password = 'qwerty123'
    host = 'localhost'
    port = '3000'

    engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{dbname}')

    return engine

# %% [markdown]
# ### 5.2. Load to "dvdrental_clean" Database

# %% [markdown]
# #### 5.2.1. Create table

# %% [markdown]
# - Buatlah table untuk database tersebut.
# - Gunakan schema berikut :
#     ```sql
#     -- Membuat skema public jika belum ada
#     CREATE SCHEMA IF NOT EXISTS public;
#
#     -- Buat tabel
#     CREATE TABLE public.actor (
#         actor_id SERIAL PRIMARY KEY,
#         last_update TIMESTAMP,
#         first_name VARCHAR,
#         last_name VARCHAR
#     );
#
#     CREATE TABLE public.store (
#         store_id SERIAL PRIMARY KEY,
#         manager_staff_id INTEGER,
#         address_id INTEGER,
#         last_update TIMESTAMP
#     );
#
#     CREATE TABLE public.address (
#         last_update TIMESTAMP,
#         city_id INTEGER,
#         address_id SERIAL PRIMARY KEY,
#         district VARCHAR,
#         phone VARCHAR,
#         postal_code VARCHAR,
#         address VARCHAR,
#         address2 VARCHAR
#     );
#
#     CREATE TABLE public.category (
#         category_id SERIAL PRIMARY KEY,
#         last_update TIMESTAMP,
#         name VARCHAR
#     );
#
#     CREATE TABLE public.city (
#         city_id SERIAL PRIMARY KEY,
#         country_id INTEGER,
#         last_update TIMESTAMP,
#         city VARCHAR
#     );
#
#     CREATE TABLE public.country (
#         country_id SERIAL PRIMARY KEY,
#         last_update TIMESTAMP,
#         country VARCHAR
#     );
#
#     CREATE TABLE public.customer (
#         active INTEGER,
#         store_id INTEGER,
#         create_date TIMESTAMP,
#         last_update TIMESTAMP,
#         customer_id SERIAL PRIMARY KEY,
#         address_id INTEGER,
#         activebool BOOLEAN,
#         first_name VARCHAR,
#         last_name VARCHAR,
#         email VARCHAR
#     );
#
#     CREATE TABLE public.film_actor (
#         actor_id SERIAL PRIMARY KEY,
#         film_id INTEGER,
#         last_update TIMESTAMP
#     );
#
#     CREATE TABLE public.film_category (
#         film_id SERIAL PRIMARY KEY,
#         category_id INTEGER,
#         last_update TIMESTAMP
#     );
#
#     CREATE TABLE public.inventory (
#         inventory_id SERIAL PRIMARY KEY,
#         film_id INTEGER,
#         store_id INTEGER,
#         last_update TIMESTAMP
#     );
#
#     CREATE TABLE public.language (
#         language_id SERIAL PRIMARY KEY,
#         last_update TIMESTAMP,
#         name VARCHAR
#     );
#
#     CREATE TABLE public.rental (
#         rental_id SERIAL PRIMARY KEY,
#         rental_date TIMESTAMP,
#         inventory_id INTEGER,
#         customer_id INTEGER,
#         return_date TIMESTAMP,
#         staff_id INTEGER,
#         last_update TIMESTAMP
#     );
#
#     CREATE TABLE public.staff (
#         picture VARCHAR,
#         address_id INTEGER,
#         store_id INTEGER,
#         active BOOLEAN,
#         last_update TIMESTAMP,
#         staff_id SERIAL PRIMARY KEY,
#         first_name VARCHAR,
#         last_name VARCHAR,
#         password VARCHAR,
#         email VARCHAR,
#         username VARCHAR
#     );
#
#     CREATE TABLE public.payment (
#         payment_id SERIAL PRIMARY KEY,
#         customer_id INTEGER,
#         staff_id INTEGER,
#         rental_id INTEGER,
#         amount FLOAT,
#         payment_date TIMESTAMP
#     );
#
#     CREATE TABLE public.film (
#         fulltext VARCHAR,
#         rating VARCHAR,
#         last_update TIMESTAMP,
#         film_id SERIAL PRIMARY KEY,
#         release_year INTEGER,
#         language_id INTEGER,
#         rental_duration INTEGER,
#         rental_rate FLOAT,
#         length INTEGER,
#         replacement_cost FLOAT,
#         title VARCHAR,
#         description VARCHAR,
#         special_features VARCHAR
#     );
#     ```

# %% [markdown]
# #### 5.2.2. Load Data

# %% [markdown]
# - Lakukan load data ke "dvdrental_analysis" database

# %%
# Your code here
...
dw_engine = dw_postgres_engine('dvdrental_clean')

for table_name, df in table_dict.items():
    try:
        df.to_sql(table_name, dw_engine, if_exists='replace', index=False)
        print(f"Table '{table_name}' has been successfully written to the database.")
    except Exception as e:
        print(f"Error writing table '{table_name}' to the database: {e}")

dw_engine.dispose()
# Out:
# Table 'city' has been successfully written to the database.
# Table 'country' has been successfully written to the database.
# Table 'actor' has been successfully written to the database.
# Table 'store' has been successfully written to the database.
# Table 'address' has been successfully written to the database.
# Table 'category' has been successfully written to the database.
# Table 'customer' has been successfully written to the database.
# Table 'film_actor' has been successfully written to the database.
# Table 'film_category' has been successfully written to the database.
# Table 'inventory' has been successfully written to the database.
# Table 'language' has been successfully written to the database.
# Table 'rental' has been successfully written to the database.
# Table 'staff' has been successfully written to the database.
# Table 'payment' has been successfully written to the database.
# Table 'film' has been successfully written to the database.

# %% [markdown]
# ### 5.3. Load to "dvdrental_analysis" Database

# %% [markdown]
# #### 5.3.1. Create Table

# %% [markdown]
# - Buatlah table untuk database tersebut.
# - Gunakan schema berikut :
#     ```sql
#     -- Membuat skema public jika belum ada
#     CREATE SCHEMA IF NOT EXISTS public;
#
#     -- Membuat tabel film_list
#     CREATE TABLE public.film_list (
#         fid SERIAL PRIMARY KEY,
#         title VARCHAR,
#         description VARCHAR,
#         category VARCHAR,
#         price FLOAT,
#         length INTEGER,
#         rating VARCHAR,
#         actors VARCHAR
#     );
#     ```

# %% [markdown]
# #### 5.3.2. Load Data

# %% [markdown]
# - Lakukan load data ke "dvdrental_analysis" database

# %%
# Your code here
# Buat engine postgres
...

dw_engine = dw_postgres_engine('dvdrental_analysis')

# Insert data ke table film_list
film_list_df.to_sql('film_list', dw_engine, if_exists='replace', index=False)

# Tutup koneksi ke database
dw_engine.dispose()

# %% [markdown]
# Untuk code dalam bentuk Python script, ada di https://github.com/rahilpacmann/case-data-wrangling
